# %%
# %%capture
# !pip install rouge bert-score rouge-score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import BertTokenizer, BertForMaskedLM, BertModel
from bert_score import BERTScorer
from rouge import Rouge
from rouge_score import rouge_scorer

# %%
references_path = "/content/drive/MyDrive/AI/MultiClinSum 2025/Data/summaries"
candidates_path = "/content/drive/MyDrive/AI/MultiClinSum 2025/Results/Baseline"
output_path = "/content/drive/MyDrive/AI/MultiClinSum 2025/Results/Paper/Baseline.xlsx"

# %%
import os

references_filenames_sorted = sorted(
    [f for f in os.listdir(references_path) if f.endswith(".txt")],
    key=lambda x: int(x.split('_')[-2].removesuffix('.txt'))
)[500:]

candidates_filenames_sorted = sorted(
    [f for f in os.listdir(candidates_path) if f.endswith(".txt")],
    key=lambda x: int(x.split('_')[-1].removesuffix('.txt'))
)

# %%
rouge_scores = []
bert_scores = []

r_scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
b_scorer = BERTScorer(model_type='bert-base-multilingual-cased') # Requires ~1.5G VRAM

for reference_filename, candidate_filename in zip(references_filenames_sorted, candidates_filenames_sorted):
  print("Processing", candidate_filename)
  with open(f'{references_path}/{reference_filename}', 'r', encoding='utf8') as reference_file:
    with open(f'{candidates_path}/{candidate_filename}', 'r', encoding='utf8') as candidate_file:
      candidate_summary = candidate_file.read()
      reference_summary = reference_file.read().strip()

      rouge_scores.append(r_scorer.score(prediction=candidate_summary, target=reference_summary))
      bert_scores.append(b_scorer.score(cands=[candidate_summary], refs=[reference_summary]))
# Out:
# Processing multiclinsum_gs_es_501.txt
# Processing multiclinsum_gs_es_502.txt
# Processing multiclinsum_gs_es_503.txt
# Processing multiclinsum_gs_es_504.txt
# Processing multiclinsum_gs_es_505.txt
# Processing multiclinsum_gs_es_506.txt
# Processing multiclinsum_gs_es_507.txt
# Processing multiclinsum_gs_es_508.txt
# Processing multiclinsum_gs_es_509.txt
# Processing multiclinsum_gs_es_510.txt
# Processing multiclinsum_gs_es_511.txt
# Processing multiclinsum_gs_es_512.txt
# Processing multiclinsum_gs_es_513.txt
# Processing multiclinsum_gs_es_514.txt
# Processing multiclinsum_gs_es_515.txt
# Processing multiclinsum_gs_es_516.txt
# Processing multiclinsum_gs_es_517.txt
# Processing multiclinsum_gs_es_518.txt
# Processing multiclinsum_gs_es_519.txt
# Processing multiclinsum_gs_es_520.txt
# Processing multiclinsum_gs_es_521.txt
# Processing multiclinsum_gs_es_522.txt
# Processing multiclinsum_gs_es_523.txt
# Processing multiclinsum_gs_es_524.txt
# Processing multiclinsum_gs_es_525.txt
# Processing multiclinsum_gs_es_526.txt
# Processing multiclinsum_gs_es_527.txt
# Processing multiclinsum_gs_es_528.txt
# Processing multiclinsum_gs_es_529.txt
# Processing multiclinsum_gs_es_530.txt
# Processing multiclinsum_gs_es_531.txt
# Processing multiclinsum_gs_es_532.txt
# Processing multiclinsum_gs_es_533.txt
# Processing multiclinsum_gs_es_534.txt
# Processing multiclinsum_gs_es_535.txt
# Processing multiclinsum_gs_es_536.txt
# Processing multiclinsum_gs_es_537.txt
# Processing multiclinsum_gs_es_538.txt
# Processing multiclinsum_gs_es_539.txt
# Processing multiclinsum_gs_es_540.txt
# Processing multiclinsum_gs_es_541.txt
# Processing multiclinsum_gs_es_542.txt
# Processing multiclinsum_gs_es_543.txt
# Processing multiclinsum_gs_es_544.txt
# Processing multiclinsum_gs_es_545.txt
# Processing multiclinsum_gs_es_546.txt
# Processing multiclinsum_gs_es_547.txt
# Processing multiclinsum_gs_es_548.txt
# Processing multiclinsum_gs_es_549.txt
# Processing multiclinsum_gs_es_550.txt
# Processing multiclinsum_gs_es_551.txt
# Processing multiclinsum_gs_es_552.txt
# Processing multiclinsum_gs_es_553.txt
# Processing multiclinsum_gs_es_554.txt
# Processing multiclinsum_gs_es_555.txt
# Processing multiclinsum_gs_es_556.txt
# Processing multiclinsum_gs_es_557.txt
# Processing multiclinsum_gs_es_558.txt
# Processing multiclinsum_gs_es_559.txt
# Processing multiclinsum_gs_es_560.txt
# Processing multiclinsum_gs_es_561.txt
# Processing multiclinsum_gs_es_562.txt
# Processing multiclinsum_gs_es_563.txt
# Processing multiclinsum_gs_es_564.txt
# Processing multiclinsum_gs_es_565.txt
# Processing multiclinsum_gs_es_566.txt
# Processing multiclinsum_gs_es_567.txt
# Processing multiclinsum_gs_es_568.txt
# Processing multiclinsum_gs_es_569.txt
# Processing multiclinsum_gs_es_570.txt
# Processing multiclinsum_gs_es_571.txt
# Processing multiclinsum_gs_es_572.txt
# Processing multiclinsum_gs_es_573.txt
# Processing multiclinsum_gs_es_574.txt
# Processing multiclinsum_gs_es_575.txt
# Processing multiclinsum_gs_es_576.txt
# Processing multiclinsum_gs_es_577.txt
# Processing multiclinsum_gs_es_578.txt
# Processing multiclinsum_gs_es_579.txt
# Processing multiclinsum_gs_es_580.txt
# Processing multiclinsum_gs_es_581.txt
# Processing multiclinsum_gs_es_582.txt
# Processing multiclinsum_gs_es_583.txt
# Processing multiclinsum_gs_es_584.txt
# Processing multiclinsum_gs_es_585.txt
# Processing multiclinsum_gs_es_586.txt
# Processing multiclinsum_gs_es_587.txt
# Processing multiclinsum_gs_es_588.txt
# Processing multiclinsum_gs_es_589.txt
# Processing multiclinsum_gs_es_590.txt
# Processing multiclinsum_gs_es_591.txt
# Processing multiclinsum_gs_es_592.txt

# %%
bert_scores
# Out:
# [(tensor([0.7441]), tensor([0.7484]), tensor([0.7462])),
#  (tensor([0.7882]), tensor([0.7745]), tensor([0.7813])),
#  (tensor([0.7292]), tensor([0.7474]), tensor([0.7382])),
#  (tensor([0.6803]), tensor([0.7442]), tensor([0.7108])),
#  (tensor([0.7369]), tensor([0.7716]), tensor([0.7539])),
#  (tensor([0.6923]), tensor([0.7713]), tensor([0.7297])),
#  (tensor([0.6852]), tensor([0.7353]), tensor([0.7094])),
#  (tensor([0.5771]), tensor([0.6694]), tensor([0.6198])),
#  (tensor([0.7549]), tensor([0.7625]), tensor([0.7587])),
#  (tensor([0.7359]), tensor([0.7574]), tensor([0.7465])),
#  (tensor([0.7189]), tensor([0.7845]), tensor([0.7503])),
#  (tensor([0.7510]), tensor([0.7566]), tensor([0.7538])),
#  (tensor([0.7038]), tensor([0.7539]), tensor([0.7280])),
#  (tensor([0.7131]), tensor([0.7794]), tensor([0.7448])),
#  (tensor([0.6971]), tensor([0.7581]), tensor([0.7263])),
#  (tensor([0.7469]), tensor([0.7888]), tensor([0.7673])),
#  (tensor([0.7237]), tensor([0.7968]), tensor([0.7585])),
#  (tensor([0.6842]), tensor([0.7652]), tensor([0.7225])),
#  (tensor([0.6834]), tensor([0.7533]), tensor([0.7167])),
#  (tensor([0.7750]), tensor([0.7576]), tensor([0.7662])),
#  (tensor([0.7778]), tensor([0.7944]), tensor([0.7860])),
#  (tensor([0.7752]), tensor([0.7777]), tensor([0.7764])),
#  (tensor([0.7214]), tensor([0.7856]), tensor([0.7521])),
#  (tensor([0.7780]), tensor([0.8081]), tensor([0.7928])),
#  (tensor([0.7715]), tensor([0.7834]), tensor([0.7774])),
#  (tensor([0.7122]), tensor([0.7311]), tensor([0.7215])),
#  (tensor([0.7459]), tensor([0.8260]), tensor([0.7839])),
#  (tensor([0.7169]), tensor([0.7524]), tensor([0.7342])),
#  (tensor([0.7096]), tensor([0.8012]), tensor([0.7526])),
#  (tensor([0.7214]), tensor([0.7571]), tensor([0.7388])),
#  (tensor([0.7520]), tensor([0.8065]), tensor([0.7783])),
#  (tensor([0.7465]), tensor([0.8484]), tensor([0.7942])),
#  (tensor([0.7224]), tensor([0.7986]), tensor([0.7586])),
#  (tensor([0.7660]), tensor([0.8043]), tensor([0.7847])),
#  (tensor([0.7333]), tensor([0.8244]), tensor([0.7762])),
#  (tensor([0.6869]), tensor([0.7682]), tensor([0.7253])),
#  (tensor([0.7239]), tensor([0.7532]), tensor([0.7383])),
#  (tensor([0.7168]), tensor([0.7664]), tensor([0.7408])),
#  (tensor([0.6710]), tensor([0.7584]), tensor([0.7120])),
#  (tensor([0.7381]), tensor([0.8247]), tensor([0.7790])),
#  (tensor([0.7222]), tensor([0.7692]), tensor([0.7449])),
#  (tensor([0.7853]), tensor([0.7636]), tensor([0.7743])),
#  (tensor([0.7129]), tensor([0.7241]), tensor([0.7185])),
#  (tensor([0.7170]), tensor([0.8191]), tensor([0.7647])),
#  (tensor([0.6991]), tensor([0.7552]), tensor([0.7261])),
#  (tensor([0.7770]), tensor([0.8322]), tensor([0.8037])),
#  (tensor([0.8131]), tensor([0.7952]), tensor([0.8041])),
#  (tensor([0.7391]), tensor([0.7943]), tensor([0.7657])),
#  (tensor([0.7171]), tensor([0.7674]), tensor([0.7414])),
#  (tensor([0.7375]), tensor([0.7898]), tensor([0.7627])),
#  (tensor([0.7295]), tensor([0.7907]), tensor([0.7589])),
#  (tensor([0.6983]), tensor([0.7743]), tensor([0.7343])),
#  (tensor([0.7379]), tensor([0.7905]), tensor([0.7633])),
#  (tensor([0.6722]), tensor([0.7397]), tensor([0.7044])),
#  (tensor([0.8022]), tensor([0.8462]), tensor([0.8236])),
#  (tensor([0.7214]), tensor([0.8458]), tensor([0.7786])),
#  (tensor([0.6975]), tensor([0.7461]), tensor([0.7210])),
#  (tensor([0.7284]), tensor([0.8005]), tensor([0.7628])),
#  (tensor([0.7044]), tensor([0.7696]), tensor([0.7356])),
#  (tensor([0.7546]), tensor([0.8299]), tensor([0.7905])),
#  (tensor([0.7646]), tensor([0.8079]), tensor([0.7857])),
#  (tensor([0.7252]), tensor([0.7746]), tensor([0.7491])),
#  (tensor([0.7473]), tensor([0.7748]), tensor([0.7608])),
#  (tensor([0.7448]), tensor([0.7753]), tensor([0.7598])),
#  (tensor([0.7525]), tensor([0.8214]), tensor([0.7855])),
#  (tensor([0.7680]), tensor([0.7921]), tensor([0.7799])),
#  (tensor([0.7791]), tensor([0.8034]), tensor([0.7911])),
#  (tensor([0.7076]), tensor([0.8074]), tensor([0.7542])),
#  (tensor([0.7281]), tensor([0.7720]), tensor([0.7494])),
#  (tensor([0.6558]), tensor([0.7072]), tensor([0.6805])),
#  (tensor([0.7500]), tensor([0.7479]), tensor([0.7490])),
#  (tensor([0.7231]), tensor([0.7547]), tensor([0.7386])),
#  (tensor([0.6878]), tensor([0.8071]), tensor([0.7427])),
#  (tensor([0.6962]), tensor([0.7689]), tensor([0.7307])),
#  (tensor([0.6779]), tensor([0.7555]), tensor([0.7146])),
#  (tensor([0.7157]), tensor([0.8156]), tensor([0.7624])),
#  (tensor([0.7284]), tensor([0.7568]), tensor([0.7423])),
#  (tensor([0.7481]), tensor([0.7857]), tensor([0.7665])),
#  (tensor([0.7009]), tensor([0.7739]), tensor([0.7356])),
#  (tensor([0.6892]), tensor([0.7729]), tensor([0.7286])),
#  (tensor([0.7380]), tensor([0.8134]), tensor([0.7738])),
#  (tensor([0.7493]), tensor([0.7882]), tensor([0.7682])),
#  (tensor([0.7040]), tensor([0.7173]), tensor([0.7106])),
#  (tensor([0.8058]), tensor([0.8682]), tensor([0.8358])),
#  (tensor([0.7845]), tensor([0.8138]), tensor([0.7989])),
#  (tensor([0.7298]), tensor([0.7207]), tensor([0.7252])),
#  (tensor([0.8022]), tensor([0.8218]), tensor([0.8119])),
#  (tensor([0.7344]), tensor([0.7983]), tensor([0.7650])),
#  (tensor([0.6987]), tensor([0.7832]), tensor([0.7385])),
#  (tensor([0.7226]), tensor([0.7832]), tensor([0.7517])),
#  (tensor([0.6918]), tensor([0.7542]), tensor([0.7217])),
#  (tensor([0.7105]), tensor([0.7862]), tensor([0.7464]))]

# %%
rougel_precision_scores = [score['rougeL'].precision for score in rouge_scores]
rougel_recall_scores = [score['rougeL'].recall for score in rouge_scores]
rougel_f1_scores = [score['rougeL'].fmeasure for score in rouge_scores]

bert_precision_scores = [score[0][0].item() for score in bert_scores]
bert_recall_scores = [score[1][0].item() for score in bert_scores]
bert_f1_scores = [score[2][0].item() for score in bert_scores]

# %%
import pandas as pd

df = pd.DataFrame({'file_name': candidates_filenames_sorted, 'rougel_precision': rougel_precision_scores, 'rougel_recall': rougel_recall_scores, 'rougel_f1': rougel_f1_scores, 'bert_precision': bert_precision_scores, 'bert_recall': bert_recall_scores, 'bert_f1': bert_f1_scores})

# %%
df
# Out:
#                      file_name  rougel_precision  rougel_recall  rougel_f1  \
# 0   multiclinsum_gs_es_501.txt          0.219512       0.270677   0.242424
# 1   multiclinsum_gs_es_502.txt          0.303191       0.252212   0.275362
# 2   multiclinsum_gs_es_503.txt          0.221818       0.273543   0.244980
# 3   multiclinsum_gs_es_504.txt          0.107143       0.349515   0.164009
# 4   multiclinsum_gs_es_505.txt          0.190751       0.362637   0.250000
# ..                         ...               ...            ...        ...
# 87  multiclinsum_gs_es_588.txt          0.159259       0.462366   0.236915
# 88  multiclinsum_gs_es_589.txt          0.157233       0.434783   0.230947
# 89  multiclinsum_gs_es_590.txt          0.182171       0.470000   0.262570
# 90  multiclinsum_gs_es_591.txt          0.141509       0.428571   0.212766
# 91  multiclinsum_gs_es_592.txt          0.170833       0.460674   0.249240
#
#     bert_precision  bert_recall   bert_f1
# 0         0.744090     0.748399  0.746238
# 1         0.788174     0.774514  0.781285
# 2         0.729242     0.747385  0.738202
# 3         0.680330     0.744212  0.710838
# 4         0.736901     0.771617  0.753860
# ..             ...          ...       ...
# 87        0.734367     0.798295  0.764998
# 88        0.698684     0.783234  0.738547
# 89        0.722556     0.783246  0.751678
# 90        0.691818     0.754242  0.721682
# 91        0.710454     0.786205  0.746412
#
# [92 rows x 7 columns]

# %%
df['rougel_precision'].describe()
# Out:
# count    92.000000
# mean      0.218984
# std       0.080227
# min       0.103175
# 25%       0.158753
# 50%       0.200372
# 75%       0.269396
# max       0.524510
# Name: rougel_precision, dtype: float64

# %%
df['rougel_recall'].describe()
# Out:
# count    92.000000
# mean      0.422506
# std       0.103966
# min       0.201342
# 25%       0.348938
# 50%       0.418815
# 75%       0.493548
# max       0.692308
# Name: rougel_recall, dtype: float64

# %%
df['rougel_f1'].describe()
# Out:
# count    92.000000
# mean      0.278332
# std       0.074913
# min       0.156962
# 25%       0.231244
# 50%       0.261462
# 75%       0.308522
# max       0.534653
# Name: rougel_f1, dtype: float64

# %%
df['bert_f1'].describe()
# Out:
# count    92.000000
# mean      0.752884
# std       0.031565
# min       0.619807
# 25%       0.734307
# 50%       0.752369
# 75%       0.774761
# max       0.835826
# Name: bert_f1, dtype: float64

# %%
df.to_excel(output_path, index=False)
